# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# Load the dataset
iris = pd.read_csv('/content/drive/MyDrive/diabetes.csv')

# Remove rows with any missing values
iris_cleaned = iris.dropna()

# Store the feature matrix (X) and response vector (y)
X = iris_cleaned.values[:, :7]
y = iris_cleaned.values[:, 8]

# Print the first 10 rows of the feature matrix and target vector
print("\nFeature Matrix :\n", X[:4, :])
print("\nTarget Vector : \n", y[:4])

# Split X and y into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# Train the model on the training set
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = gnb.predict(X_test)

# Print the test samples, predicted values, and actual values
print("\nPredicted values by the model :")
for i in range(10): #range(len(X_test))
    print("\n", X_test[i], "-->", "(Predicted Values)", y_pred[i], "(Actual values)", y_test[i])

# Define a function to calculate accuracy and display the confusion matrix
def cal_accuracy(y_test, y_pred):
    cm = confusion_matrix(y_test, y_pred)
    print("\n\nConfusion Matrix: \n", cm)
    print("\nAccuracy: ", accuracy_score(y_test, y_pred) * 100)
    print("\nReport: \n", classification_report(y_test, y_pred))
    # Plotting the confusion matrix heatmap
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix Heatmap')
    plt.show()

# Call the function to calculate accuracy and display the confusion matrix
cal_accuracy(y_test, y_pred)
# Out:
# Feature Matrix :
#  [[6.00e+00 1.48e+02 7.20e+01 3.50e+01 0.00e+00 3.36e+01 6.27e-01]
#  [1.00e+00 8.50e+01 6.60e+01 2.90e+01 0.00e+00 2.66e+01 3.51e-01]
#  [8.00e+00 1.83e+02 6.40e+01 0.00e+00 0.00e+00 2.33e+01 6.72e-01]
#  [1.00e+00 8.90e+01 6.60e+01 2.30e+01 9.40e+01 2.81e+01 1.67e-01]]
#
# Target Vector :
#  [1. 0. 1. 0.]
#
# Predicted values by the model :
#
#  [  7.    136.     74.     26.    135.     26.      0.647] --> (Predicted Values) 0.0 (Actual values) 0.0
#
#  [  1.    151.     60.      0.      0.     26.1     0.179] --> (Predicted Values) 0.0 (Actual values) 0.0
#
#  [  6.    109.     60.     27.      0.     25.      0.206] --> (Predicted Values) 0.0 (Actual values) 0.0
#
#  [ 3.    61.    82.    28.     0.    34.4    0.243] --> (Predicted Values) 0.0 (Actual values) 0.0
#
#  [  1.    116.     78.     29.    180.     36.1     0.496] --> (Predicted Values) 0.0 (Actual values) 0.0
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
