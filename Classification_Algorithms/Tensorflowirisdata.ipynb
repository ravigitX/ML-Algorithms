# %%
# Tried tensorflow to give the epochs as the arguments on the fit function 
# In normal Classifcation or Regssion Model We have to use for loops to give the epochs for the data to train the model

import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

df = pd.read_csv(r'C:\Users\ravi\Desktop\ML Algorithms\Datasets\iris.data', header=None)
X = df.iloc[:, :4].values
y = df.iloc[:, 4].values
le = LabelEncoder()
y = le.fit_transform(y)
y = to_categorical(y)

model = Sequential()
model.add(Dense(64, activation='relu', input_shape=[4]))
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['acc'])
model.fit(X, y, epochs=20)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open('iris.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# c:\Users\ravi\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - acc: 0.3268 - loss: 1.2585
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.3605 - loss: 1.0695
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6534 - loss: 0.9687
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.8392 - loss: 0.9088
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.8428 - loss: 0.8624
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.8455 - loss: 0.8243
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7241 - loss: 0.7746
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.8285 - loss: 0.7418
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9143 - loss: 0.7302
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.8888 - loss: 0.7078
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.8317 - loss: 0.6778
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.8859 - loss: 0.6812
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7805 - loss: 0.6157
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9514 - loss: 0.5924
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.8163 - loss: 0.5817
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.9025 - loss: 0.5888
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.8399 - loss: 0.5668
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9842 - loss: 0.5576
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9453 - loss: 0.5597
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.8488 - loss: 0.5367
# INFO:tensorflow:Assets written to: C:\Users\ravi\AppData\Local\Temp\tmpp3sil_7m\assets
# INFO:tensorflow:Assets written to: C:\Users\ravi\AppData\Local\Temp\tmpp3sil_7m\assets
# Saved artifact at 'C:\Users\ravi\AppData\Local\Temp\tmpp3sil_7m'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 4), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   2615026125712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2613897674384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2613898364112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2613898364880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2613898362960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2613898365264: TensorSpec(shape=(), dtype=tf.resource, name=None)
