# %%
# Importing the required packages
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import seaborn as sns
import matplotlib.pyplot as plt


# Function to import the dataset
def importdata():
    balance_data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/balance-scale/balance-scale.data',sep=',', header=None)

    # Displaying dataset information
    print("Dataset Length: ", len(balance_data))
    print("Dataset Shape: ", balance_data.shape)
    print("Dataset: ", balance_data.head())

    return balance_data

# Function to split the dataset into features and target variables
def splitdataset(balance_data):

    # Separating the target variable
    X = balance_data.values[:, 1:5]
    Y = balance_data.values[:, 0]

    # Splitting the dataset into train and test
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=0.3, random_state=100)

    return X, Y, X_train, X_test, y_train, y_test

#TRAINING USING GINI INDEX
def train_using_gini(X_train, X_test, y_train):

    # Creating the classifier object
    clf_gini = DecisionTreeClassifier(criterion="gini",
                                      random_state=100, max_depth=3, min_samples_leaf=5)

    # Performing training
    clf_gini.fit(X_train, y_train)
    return clf_gini

#TRAINING USING ENTROPY
def train_using_entropy(X_train,X_test, y_train):

    # Decision tree with entropy
    clf_entropy = DecisionTreeClassifier(
        criterion="entropy", random_state=100,
        max_depth=3, min_samples_leaf=5)

    # Performing training
    clf_entropy.fit(X_train, y_train)
    return clf_entropy

# Function to make predictions
def prediction(X_test, clf_object):
    y_pred = clf_object.predict(X_test)
    #print("Predicted values:")
    print(y_pred)
    return y_pred

# Placeholder function for cal_accuracy
def cal_accuracy(y_test, y_pred):
    cm = confusion_matrix(y_test, y_pred)
    print("\n Confusion Matrix: ",cm)
    print("\n Accuracy : ",
          accuracy_score(y_test, y_pred)*100)
    print("\n Report :\n",classification_report(y_test, y_pred))

    # Plotting the confusion matrix heatmap
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix Heatmap')
    plt.show()

# Function to plot the decision tree
def plot_decision_tree(clf_object, feature_names, class_names):
    plt.figure(figsize=(15, 10))
    tree.plot_tree(clf_object, filled=True, feature_names=feature_names, class_names=class_names, rounded=True)
    plt.show()
if __name__ == "__main__":
    data = importdata()
    X, Y, X_train, X_test, y_train, y_test = splitdataset(data)

    clf_gini = train_using_gini(X_train, X_test, y_train)
    clf_entropy = train_using_entropy(X_train, X_test, y_train)

    # Visualizing the Decision Trees
    #plot_decision_tree(clf_gini, ['X1', 'X2', 'X3', 'X4'], ['L', 'B', 'R'])
    #plot_decision_tree(clf_entropy, ['X1', 'X2', 'X3', 'X4'], ['L', 'B', 'R'])


# Operational Phase
#print("Results Using Gini Index:")
y_pred_gini = prediction(X_test, clf_gini)

#for i in range(len(X_test)):
        #print(X_test[i],"-->",y_pred_gini[i])
print("\nAccuracy and calculations for GINI INDEX :")
cal_accuracy(y_test, y_pred_gini)

#print("Results Using Entropy:")
y_pred_entropy = prediction(X_test, clf_entropy)
for i in range(len(X_test)):
        print(X_test[i],"-->", "(Predicted Values)",y_pred_entropy[i], "(Actual values)",y_test[i])
print("\nAccuracy and calculations for ENTROPY :")
cal_accuracy(y_test, y_pred_entropy)
# Out:
# Dataset Length:  625
# Dataset Shape:  (625, 5)
# Dataset:     0  1  2  3  4
# 0  B  1  1  1  1
# 1  R  1  1  1  2
# 2  R  1  1  1  3
# 3  R  1  1  1  4
# 4  R  1  1  1  5
# ['R' 'L' 'R' 'R' 'R' 'L' 'R' 'L' 'L' 'L' 'R' 'L' 'L' 'L' 'R' 'L' 'R' 'L'
#  'L' 'R' 'L' 'R' 'L' 'L' 'R' 'L' 'L' 'L' 'R' 'L' 'L' 'L' 'R' 'L' 'L' 'L'
#  'L' 'R' 'L' 'L' 'R' 'L' 'R' 'L' 'R' 'R' 'L' 'L' 'R' 'L' 'R' 'R' 'L' 'R'
#  'R' 'L' 'R' 'R' 'L' 'L' 'R' 'R' 'L' 'L' 'L' 'L' 'L' 'R' 'R' 'L' 'L' 'R'
#  'R' 'L' 'R' 'L' 'R' 'R' 'R' 'L' 'R' 'L' 'L' 'L' 'L' 'R' 'R' 'L' 'R' 'L'
#  'R' 'R' 'L' 'L' 'L' 'R' 'R' 'L' 'L' 'L' 'R' 'L' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'R' 'L' 'R' 'R' 'L' 'R' 'R' 'R' 'R' 'R' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'R' 'R' 'R' 'R' 'L' 'R' 'R' 'R' 'L' 'L' 'R' 'L' 'R' 'L' 'R'
#  'L' 'L' 'R' 'L' 'L' 'R' 'L' 'R' 'L' 'R' 'R' 'R' 'L' 'R' 'R' 'R' 'R' 'R'
#  'L' 'L' 'R' 'R' 'R' 'R' 'L' 'R' 'R' 'R' 'L' 'R' 'L' 'L' 'L' 'L' 'R' 'R'
#  'L' 'R' 'R' 'L' 'L' 'R' 'R' 'R']
#
# Accuracy and calculations for GINI INDEX :
#
#  Confusion Matrix:  [[ 0  6  7]
#  [ 0 67 18]
#  [ 0 19 71]]
#
#  Accuracy :  73.40425531914893
#
#  Report :
#                precision    recall  f1-score   support
#
#            B       0.00      0.00      0.00        13
#            L       0.73      0.79      0.76        85
#            R       0.74      0.79      0.76        90
#
#     accuracy                           0.73       188
#    macro avg       0.49      0.53      0.51       188
# weighted avg       0.68      0.73      0.71       188
# c:\Users\ravi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ravi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ravi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ['R' 'L' 'R' 'L' 'R' 'L' 'R' 'L' 'R' 'R' 'R' 'R' 'L' 'L' 'R' 'L' 'R' 'L'
#  'L' 'R' 'L' 'R' 'L' 'L' 'R' 'L' 'R' 'L' 'R' 'L' 'R' 'L' 'R' 'L' 'L' 'L'
#  'L' 'L' 'R' 'L' 'R' 'L' 'R' 'L' 'R' 'R' 'L' 'L' 'R' 'L' 'L' 'R' 'L' 'L'
#  'R' 'L' 'R' 'R' 'L' 'R' 'R' 'R' 'L' 'L' 'R' 'L' 'L' 'R' 'L' 'L' 'L' 'R'
#  'R' 'L' 'R' 'L' 'R' 'R' 'R' 'L' 'R' 'L' 'L' 'L' 'L' 'R' 'R' 'L' 'R' 'L'
#  'R' 'R' 'L' 'L' 'L' 'R' 'R' 'L' 'L' 'L' 'R' 'L' 'L' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'R' 'L' 'R' 'R' 'L' 'R' 'R' 'L' 'R' 'R' 'L' 'R' 'R' 'R' 'L' 'L'
#  'L' 'L' 'L' 'R' 'R' 'R' 'R' 'L' 'R' 'R' 'R' 'L' 'L' 'R' 'L' 'R' 'L' 'R'
#  'L' 'R' 'R' 'L' 'L' 'R' 'L' 'R' 'R' 'R' 'R' 'R' 'L' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'R' 'L' 'R' 'R' 'L' 'R' 'L' 'R' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'R'
#  'R' 'R' 'L' 'L' 'L' 'R' 'R' 'R']
# [4 4 3 3] --> (Predicted Values) R (Actual values) L
# [2 4 1 1] --> (Predicted Values) L (Actual values) L
# [4 1 5 3] --> (Predicted Values) R (Actual values) R
# [1 4 1 1] --> (Predicted Values) L (Actual values) L
# [3 1 2 5] --> (Predicted Values) R (Actual values) R
# [3 1 3 1] --> (Predicted Values) L (Actual values) B
# [5 1 3 4] --> (Predicted Values) R (Actual values) R
# [4 3 1 3] --> (Predicted Values) L (Actual values) L
# [4 1 1 2] --> (Predicted Values) R (Actual values) L
# [2 2 2 3] --> (Predicted Values) R (Actual values) R
# [4 4 5 3] --> (Predicted Values) R (Actual values) L
# [4 1 2 1] --> (Predicted Values) R (Actual values) L
# [5 1 4 2] --> (Predicted Values) L (Actual values) R
# [2 4 2 2] --> (Predicted Values) L (Actual values) L
# [1 3 4 5] --> (Predicted Values) R (Actual values) R
# [2 2 5 2] --> (Predicted Values) L (Actual values) R
# [4 5 3 3] --> (Predicted Values) R (Actual values) L
# [5 3 3 1] --> (Predicted Values) L (Actual values) L
# [4 2 2 4] --> (Predicted Values) L (Actual values) B
# [5 5 3 5] --> (Predicted Values) R (Actual values) L
# [5 1 3 2] --> (Predicted Values) L (Actual values) R
# [4 4 4 3] --> (Predicted Values) R (Actual values) L
# [2 3 4 2] --> (Predicted Values) L (Actual values) R
# [5 4 1 3] --> (Predicted Values) L (Actual values) L
# [2 2 5 4] --> (Predicted Values) R (Actual values) R
# [4 5 2 5] --> (Predicted Values) L (Actual values) L
# [5 1 2 1] --> (Predicted Values) R (Actual values) L
# [4 3 2 4] --> (Predicted Values) L (Actual values) L
# [4 3 5 5] --> (Predicted Values) R (Actual values) R
# [4 2 1 3] --> (Predicted Values) L (Actual values) L
# [2 2 1 3] --> (Predicted Values) R (Actual values) L
# [3 4 3 1] --> (Predicted Values) L (Actual values) L
# [3 4 3 5] --> (Predicted Values) R (Actual values) R
# [3 4 2 1] --> (Predicted Values) L (Actual values) L
# [2 4 2 3] --> (Predicted Values) L (Actual values) L
# [5 3 2 3] --> (Predicted Values) L (Actual values) L
# [2 1 4 1] --> (Predicted Values) L (Actual values) R
# [1 5 1 4] --> (Predicted Values) L (Actual values) L
# [2 2 2 1] --> (Predicted Values) R (Actual values) L
# [3 1 4 1] --> (Predicted Values) L (Actual values) R
# [3 1 1 4] --> (Predicted Values) R (Actual values) R
# [5 3 1 3] --> (Predicted Values) L (Actual values) L
# [1 1 1 4] --> (Predicted Values) R (Actual values) R
# [3 3 3 1] --> (Predicted Values) L (Actual values) L
# [1 2 5 4] --> (Predicted Values) R (Actual values) R
# [4 2 4 3] --> (Predicted Values) R (Actual values) R
# [5 4 2 3] --> (Predicted Values) L (Actual values) L
# [2 3 2 5] --> (Predicted Values) L (Actual values) R
# [4 3 4 5] --> (Predicted Values) R (Actual values) R
# [3 4 2 2] --> (Predicted Values) L (Actual values) L
# [1 5 2 2] --> (Predicted Values) L (Actual values) L
# [3 1 4 4] --> (Predicted Values) R (Actual values) R
# [2 5 3 1] --> (Predicted Values) L (Actual values) L
# [1 5 2 1] --> (Predicted Values) L (Actual values) L
# [3 1 5 3] --> (Predicted Values) R (Actual values) R
# [4 3 1 1] --> (Predicted Values) L (Actual values) L
# [1 1 5 3] --> (Predicted Values) R (Actual values) R
# [1 5 4 3] --> (Predicted Values) R (Actual values) R
# [3 3 4 1] --> (Predicted Values) L (Actual values) L
# [2 1 1 1] --> (Predicted Values) R (Actual values) L
# [1 2 2 2] --> (Predicted Values) R (Actual values) R
# [2 1 1 3] --> (Predicted Values) R (Actual values) R
# [5 2 1 3] --> (Predicted Values) L (Actual values) L
# [3 1 5 1] --> (Predicted Values) L (Actual values) R
# [2 2 1 4] --> (Predicted Values) R (Actual values) B
# [5 2 5 2] --> (Predicted Values) L (Actual values) B
# [2 1 3 2] --> (Predicted Values) L (Actual values) R
# [1 4 5 3] --> (Predicted Values) R (Actual values) R
# [1 3 1 5] --> (Predicted Values) L (Actual values) R
# [3 4 5 1] --> (Predicted Values) L (Actual values) L
# [2 3 5 1] --> (Predicted Values) L (Actual values) L
# [4 1 1 4] --> (Predicted Values) R (Actual values) B
# [2 3 5 4] --> (Predicted Values) R (Actual values) R
# [4 5 3 2] --> (Predicted Values) L (Actual values) L
# [2 2 5 5] --> (Predicted Values) R (Actual values) R
# [4 4 2 3] --> (Predicted Values) L (Actual values) L
# [5 1 1 4] --> (Predicted Values) R (Actual values) L
# [1 3 5 3] --> (Predicted Values) R (Actual values) R
# [3 1 4 3] --> (Predicted Values) R (Actual values) R
# [2 4 2 1] --> (Predicted Values) L (Actual values) L
# [1 1 2 5] --> (Predicted Values) R (Actual values) R
# [4 2 3 2] --> (Predicted Values) L (Actual values) L
# [3 3 5 1] --> (Predicted Values) L (Actual values) L
# [5 2 3 2] --> (Predicted Values) L (Actual values) L
# [3 2 2 3] --> (Predicted Values) L (Actual values) B
# [3 4 3 4] --> (Predicted Values) R (Actual values) B
# [5 1 2 4] --> (Predicted Values) R (Actual values) R
# [5 5 1 3] --> (Predicted Values) L (Actual values) L
# [1 5 4 4] --> (Predicted Values) R (Actual values) R
# [4 5 2 2] --> (Predicted Values) L (Actual values) L
# [1 2 4 1] --> (Predicted Values) R (Actual values) R
# [1 1 3 3] --> (Predicted Values) R (Actual values) R
# [4 4 2 1] --> (Predicted Values) L (Actual values) L
# [4 4 4 1] --> (Predicted Values) L (Actual values) L
# [3 3 2 2] --> (Predicted Values) L (Actual values) L
# [2 1 2 4] --> (Predicted Values) R (Actual values) R
# [3 1 3 4] --> (Predicted Values) R (Actual values) R
# [3 5 1 3] --> (Predicted Values) L (Actual values) L
# [4 1 5 1] --> (Predicted Values) L (Actual values) R
# [4 2 5 1] --> (Predicted Values) L (Actual values) L
# [3 1 1 3] --> (Predicted Values) R (Actual values) B
# [3 4 4 2] --> (Predicted Values) L (Actual values) L
# [1 4 1 4] --> (Predicted Values) L (Actual values) B
# [4 2 5 4] --> (Predicted Values) R (Actual values) R
# [3 4 3 3] --> (Predicted Values) R (Actual values) L
# [1 5 3 5] --> (Predicted Values) R (Actual values) R
# [1 2 5 2] --> (Predicted Values) R (Actual values) R
# [3 1 2 3] --> (Predicted Values) R (Actual values) R
# [5 5 5 3] --> (Predicted Values) R (Actual values) L
# [2 3 1 1] --> (Predicted Values) L (Actual values) L
# [4 1 1 5] --> (Predicted Values) R (Actual values) R
# [4 4 2 4] --> (Predicted Values) L (Actual values) L
# [5 1 5 3] --> (Predicted Values) R (Actual values) R
# [4 2 5 3] --> (Predicted Values) R (Actual values) R
# [3 5 4 2] --> (Predicted Values) L (Actual values) L
# [1 2 1 1] --> (Predicted Values) R (Actual values) L
# [3 4 4 3] --> (Predicted Values) R (Actual values) B
# [1 5 2 4] --> (Predicted Values) L (Actual values) R
# [1 1 4 1] --> (Predicted Values) R (Actual values) R
# [1 3 5 4] --> (Predicted Values) R (Actual values) R
# [3 2 1 2] --> (Predicted Values) L (Actual values) L
# [2 1 5 5] --> (Predicted Values) R (Actual values) R
# [2 2 2 5] --> (Predicted Values) R (Actual values) R
# [2 2 1 5] --> (Predicted Values) R (Actual values) R
# [2 5 1 1] --> (Predicted Values) L (Actual values) L
# [3 3 1 3] --> (Predicted Values) L (Actual values) L
# [3 4 2 4] --> (Predicted Values) L (Actual values) L
# [3 2 1 5] --> (Predicted Values) L (Actual values) L
# [5 4 2 4] --> (Predicted Values) L (Actual values) L
# [4 1 4 3] --> (Predicted Values) R (Actual values) R
# [5 2 3 4] --> (Predicted Values) R (Actual values) R
# [5 3 5 5] --> (Predicted Values) R (Actual values) R
# [4 1 3 3] --> (Predicted Values) R (Actual values) R
# [5 3 4 1] --> (Predicted Values) L (Actual values) L
# [2 1 4 3] --> (Predicted Values) R (Actual values) R
# [4 2 3 3] --> (Predicted Values) R (Actual values) R
# [5 1 5 4] --> (Predicted Values) R (Actual values) R
# [5 4 3 1] --> (Predicted Values) L (Actual values) L
# [3 4 2 5] --> (Predicted Values) L (Actual values) L
# [3 3 5 4] --> (Predicted Values) R (Actual values) R
# [3 4 1 2] --> (Predicted Values) L (Actual values) L
# [5 5 5 4] --> (Predicted Values) R (Actual values) L
# [4 3 2 1] --> (Predicted Values) L (Actual values) L
# [4 2 5 5] --> (Predicted Values) R (Actual values) R
# [5 3 2 5] --> (Predicted Values) L (Actual values) L
# [4 1 1 1] --> (Predicted Values) R (Actual values) L
# [5 2 4 5] --> (Predicted Values) R (Actual values) R
# [5 4 4 1] --> (Predicted Values) L (Actual values) L
# [4 1 5 2] --> (Predicted Values) L (Actual values) R
# [1 1 4 5] --> (Predicted Values) R (Actual values) R
# [5 5 2 4] --> (Predicted Values) L (Actual values) L
# [5 5 4 3] --> (Predicted Values) R (Actual values) L
# [5 1 1 1] --> (Predicted Values) R (Actual values) L
# [1 2 1 5] --> (Predicted Values) R (Actual values) R
# [1 5 5 5] --> (Predicted Values) R (Actual values) R
# [2 3 3 5] --> (Predicted Values) R (Actual values) R
# [5 3 1 4] --> (Predicted Values) L (Actual values) L
# [2 4 5 3] --> (Predicted Values) R (Actual values) R
# [4 4 4 4] --> (Predicted Values) R (Actual values) B
# [5 3 3 3] --> (Predicted Values) R (Actual values) L
# [1 2 1 3] --> (Predicted Values) R (Actual values) R
# [3 1 1 5] --> (Predicted Values) R (Actual values) R
# [1 1 2 1] --> (Predicted Values) R (Actual values) R
# [2 4 1 4] --> (Predicted Values) L (Actual values) L
# [1 2 4 5] --> (Predicted Values) R (Actual values) R
# [1 5 2 5] --> (Predicted Values) L (Actual values) R
# [4 5 4 3] --> (Predicted Values) R (Actual values) L
# [2 5 4 5] --> (Predicted Values) R (Actual values) R
# [2 2 4 2] --> (Predicted Values) L (Actual values) R
# [3 2 3 3] --> (Predicted Values) R (Actual values) R
# [1 3 2 2] --> (Predicted Values) L (Actual values) R
# [5 1 1 5] --> (Predicted Values) R (Actual values) B
# [2 4 5 2] --> (Predicted Values) L (Actual values) R
# [4 1 5 5] --> (Predicted Values) R (Actual values) R
# [2 2 3 1] --> (Predicted Values) L (Actual values) L
# [4 1 4 2] --> (Predicted Values) L (Actual values) R
# [5 2 2 5] --> (Predicted Values) L (Actual values) B
# [3 5 4 1] --> (Predicted Values) L (Actual values) L
# [1 4 2 5] --> (Predicted Values) L (Actual values) R
# [1 2 3 3] --> (Predicted Values) R (Actual values) R
# [1 1 2 2] --> (Predicted Values) R (Actual values) R
# [2 2 4 5] --> (Predicted Values) R (Actual values) R
# [1 3 2 4] --> (Predicted Values) L (Actual values) R
# [3 5 3 2] --> (Predicted Values) L (Actual values) L
# [5 5 3 1] --> (Predicted Values) L (Actual values) L
# [4 1 1 3] --> (Predicted Values) R (Actual values) L
# [1 4 5 4] --> (Predicted Values) R (Actual values) R
# [3 3 4 5] --> (Predicted Values) R (Actual values) R
#
# Accuracy and calculations for ENTROPY :
#
#  Confusion Matrix:  [[ 0  6  7]
#  [ 0 63 22]
#  [ 0 20 70]]
#
#  Accuracy :  70.74468085106383
#
#  Report :
#                precision    recall  f1-score   support
#
#            B       0.00      0.00      0.00        13
#            L       0.71      0.74      0.72        85
#            R       0.71      0.78      0.74        90
#
#     accuracy                           0.71       188
#    macro avg       0.47      0.51      0.49       188
# weighted avg       0.66      0.71      0.68       188
# c:\Users\ravi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ravi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ravi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
